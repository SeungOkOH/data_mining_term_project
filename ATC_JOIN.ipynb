# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df2017 = pd.read_csv('/content/drive/MyDrive/prescription_2017.csv')

# %%
df2017

# %%
def create_new_column(value):
    return value[:4] + value[6]

df2017['5_GNL'] = df2017['GNL_NM_CD'].apply(create_new_column)

# %%
ATC_mapping = pd.read_csv('/content/drive/MyDrive/ATC_mapping.csv')

# %%
ATC_mapping
# Out:
#       mfds_no  GNL_NM_CD      ATC   ATC_name
# 0         111  157030BIJ  N01AX07  etomidate
# 1         111  179531BIJ  N01AX03   ketamine
# 2         111  179532BIJ  N01AX03   ketamine
# 3         111  179533BIJ  N01AX03   ketamine
# 4         111  219830BIJ  N01AX10   propofol
# ...       ...        ...      ...        ...
# 4460      821  630904CSI  N02AB03   fentanyl
# 4461      821  630910CSI  N02AB03   fentanyl
# 4462      821  630907CSI  N02AB03   fentanyl
# 4463      821  630911CSI  N02AB03   fentanyl
# 4464      821  630901CSI  N02AB03   fentanyl
#
# [4465 rows x 4 columns]

# %%
ATC_mapping = ATC_mapping.drop(columns = 'ATC_name')

# %%
result = pd.merge(df2017, ATC_mapping, on='GNL_NM_CD', how='inner')

# %%
result

# %%
result = result.drop(columns = ['RECU_FR_DT', 'DD_MQTY_FREQ', 'DD_EXEC_FREQ', 'MDCN_EXEC_FREQ', 'UN_COST'])
result = result.sort_values(by=['KEY_SEQ', 'SEQ_NO'])
result
# Out:
#           IDV_ID   KEY_SEQ  SEQ_NO  AGE_GROUP  SIDO  GNL_NM_CD  5_GNL  \
# 0         622888         1       1         12    47  235401ACH  2354A
# 23701     622888         1       2         12    47  186101ATB  1861A
# 824102    622888         1       3         12    47  220902ATB  2209A
# 1292477   622888         1       4         12    47  268000ATB  2680A
# 1440509   571226         2       1          3    41  535000ASY  5350A
# ...          ...       ...     ...        ...   ...        ...    ...
# 27193725  246906  12270977       1         17    45  196201ATB  1962A
# 5727502   246906  12270977       2         17    45  378601ATB  3786A
# 11146086  246906  12270977       3         17    45  160601ATB  1606A
# 31533476  850473  12270979       1         14    28  530054COS  5300C
# 25602141  850473  12270979       2         14    28  203936COS  2039C
#
#           mfds_no      ATC
# 0             232    A02BX
# 23701         114    M01AE
# 824102        222  R01BA02
# ...

# %%
result.to_csv('/content/drive/MyDrive/prescription_2017_atc.csv')
